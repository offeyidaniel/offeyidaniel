# %% [markdown]
# # 6.1 Cleaning Data PART1: Preparing Data

# %% [markdown]
# ## Importing libaries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
# Assign path variable
path = '/Users/mariamaske/World Happiness Data/02 Data/Original Data'

# %% [markdown]
# ## Preparing the data set
# #### The goal of the following code (section) is to create an overall data set from the individual data sets that exist individually for the years 2015-2023.For this purpose, an additional column is added to each data set, which contains the year of the respective data set, so that the development of the happiness score from 2015-2023 can be shown with the total data set.

# %% [markdown]
# ### Preparing dataset 2015

# %%
# Join path orders.csv
df_15 = pd.read_csv(os.path.join(path,'2015.csv'), index_col = False)

# %%
df_15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# rename columns: Since in the originally published Happiness reports the category is actually called Social Support and not Familiy, I rename this column so that all the datasets can be better merged. 
df_15.rename(columns = {'Family' : 'Social Support'}, inplace = True)

# %%
df_15['Year'] = 2015

# %%
df_15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)  Social Support  \
# 0         0.03411                   1.39651         1.34951
# 1         0.04884                   1.30232         1.40223
# 2         0.03328                   1.32548         1.36058
# 3         0.03880                   1.45900         1.33095
# 4         0.03553                   1.32629         1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ### Preparing dataset 2016

# %%
# Join path orders.csv
df_16 = pd.read_csv(os.path.join(path,'2016.csv'), index_col = False)

# %%
df_16.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
# rename columns: Since in the originally published Happiness reports the category is actually called Social Support and not Familiy, I rename this column so that all the datasets can be better merged. 
df_16.rename(columns = {'Family' : 'Social Support'}, inplace = True)

# %%
df_16['Year'] = 2016

# %%
df_16.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)  Social Support  Health (Life Expectancy)  \
# 0                   1.44178         1.16374                   0.79504
# 1                   1.52733         1.14524                   0.86303
# ...

# %% [markdown]
# ### Preparing dataset 2017

# %%
# Join path orders.csv
df_17 = pd.read_csv(os.path.join(path,'2017.csv'), index_col = False)

# %%
df_17.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
# rename column Happiness.Rank to Happiness Rank
df_17.rename(columns = {'Family' : 'Social Support','Happiness.Rank' : 'Happiness Rank','Happiness.Score' : 'Happiness Score','Trust..Government.Corruption.' : 'Trust (Government Corruption)','Health..Life.Expectancy.' : 'Health (Life Expectancy)','Economy..GDP.per.Capita.' : 'Economy (GDP per Capita)', 'Dystopia.Residual' : 'Dystopia Residual', 'Whisker.high' : 'Upper Confidence Interval', 'Whisker.low' : 'Lower Confidence Interval'}, inplace = True)

# %%
df_17['Year'] = 2017

# %%
# creating a subset with the columns Country and Region from the df_15 dataframe so I can merge the subset with other dataframes like the df_17 dataframe to establish a region column in all dataframes
df_region = df_15[['Country','Region']]

# %%
df_region.head()
# Out:
#        Country          Region
# 0  Switzerland  Western Europe
# 1      Iceland  Western Europe
# 2      Denmark  Western Europe
# 3       Norway  Western Europe
# 4       Canada   North America

# %%
#Merge the two dataframes with 'country' as the key
df_17_merged = df_17.merge(df_region, on = 'Country', indicator = True)

# %%
df_17_merged.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Upper Confidence Interval  \
# 0       Norway               1            7.537                   7.594445
# 1      Denmark               2            7.522                   7.581728
# 2      Iceland               3            7.504                   7.622030
# 3  Switzerland               4            7.494                   7.561772
# 4      Finland               5            7.469                   7.527542
#
#    Lower Confidence Interval  Economy (GDP per Capita)  Social Support  \
# 0                   7.479556                  1.616463        1.533524
# 1                   7.462272                  1.482383        1.551122
# 2                   7.385970                  1.480633        1.610574
# 3                   7.426227                  1.564980        1.516912
# 4                   7.410458                  1.443572        1.540247
#
#    Health (Life Expectancy)   Freedom  Generosity  \
# ...

# %%
df_17_merged['_merge'].value_counts()
# Out:
# both          149
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %% [markdown]
# ### Preparing dataset 2018

# %%
# Join path orders.csv
df_18 = pd.read_csv(os.path.join(path,'2018.csv'), index_col = False)

# %%
df_18.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
# rename columns
df_18.rename(columns = {'Social support':'Social Support','GDP per capita': 'Economy (GDP per Capita)','Overall rank' : 'Happiness Rank','Score' : 'Happiness Score', 'Country or region':'Country', 'Perceptions of corruption':'Trust (Government Corruption)', 'Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices' : 'Freedom'}, inplace = True)

# %%
df_18['Year'] = 2018

# %%
#Merge the two dataframes with 'country' as the key
df_18_merged = df_18.merge(df_region, on = 'Country', indicator = True)

# %%
df_18_merged.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Social Support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.592                     0.874    0.681       0.202
# 1           1.582                     0.861    0.686       0.286
# 2           1.590                     0.868    0.683       0.284
# 3           1.644                     0.914    0.677       0.353
# 4           1.549                     0.927    0.660       0.256
#
#    Trust (Government Corruption)  Year          Region _merge
# 0                          0.393  2018  Western Europe   both
# ...

# %%
# rename columns
df_18_merged.rename(columns = {'Trust (Government Corruption' : 'Trust (Government Corruption)'}, inplace = True)

# %%
df_18_merged['_merge'].value_counts()
# Out:
# both          150
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %% [markdown]
# ### Preparing dataset 2019

# %%
# Join path orders.csv
df_19 = pd.read_csv(os.path.join(path,'2019.csv'), index_col = False)

# %%
df_19.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# rename columns
df_19.rename(columns = {'Social support':'Social Support','GDP per capita':'Economy (GDP per Capita)','Overall rank' : 'Happiness Rank','Score' : 'Happiness Score', 'Country or region':'Country', 'Perceptions of corruption':'Trust (Government Corruption)', 'Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices' : 'Freedom'}, inplace = True)

# %%
df_19['Year'] = 2019

# %%
#Merge the two dataframes with 'country' as the key
df_19_merged = df_19.merge(df_region, on = 'Country', indicator = True)

# %%
df_19_merged.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.769                     1.340
# 1               2      Denmark            7.600                     1.383
# 2               3       Norway            7.554                     1.488
# 3               4      Iceland            7.494                     1.380
# 4               5  Netherlands            7.488                     1.396
#
#    Social Support  Health (Life Expectancy)  Freedom  Generosity  \
# 0           1.587                     0.986    0.596       0.153
# 1           1.573                     0.996    0.592       0.252
# 2           1.582                     1.028    0.603       0.271
# 3           1.624                     1.026    0.591       0.354
# 4           1.522                     0.999    0.557       0.322
#
#    Trust (Government Corruption)  Year          Region _merge
# 0                          0.393  2019  Western Europe   both
# ...

# %%
df_19_merged['_merge'].value_counts()
# Out:
# both          149
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %% [markdown]
# ### Preparing dataset 2020

# %%
# Join path orders.csv
df_20 = pd.read_csv(os.path.join(path,'2020.csv'), index_col = False)

# %%
df_20.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
# rename columns
df_20.rename(columns = {'Social support':'Social Support','Logged GDP per capita' : 'Economy (GDP per Capita)','Standard error of ladder score' : 'Standard error of Happiness score','Ladder score in Dystopia' : 'Dystopia score','Dystopia + residual' : 'Dystopia Residual','Regional indicator' : 'Region','Ladder score' : 'Happiness Score', 'Country name':'Country', 'Perceptions of corruption':'Trust (Government Corruption)', 'Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices' : 'Freedom', 'upperwhisker' : 'Upper Confidence Interval', 'lowerwhisker' : 'Lower Confidence Interval'}, inplace = True)

# %%
df_20['Year'] = 2020

# %%
df_20.shape
# Out:
# (153, 21)

# %%
# Since the df_20 dataframe didn't have the "Happiness Rank"- column I created the column by importing the column from the df_15 dataframe. We dont't need a specific key here because we only want the numbers 1 to 153 in that order.
df_20['Happiness Rank'] = df_19['Happiness Rank']

# %%
df_20.head()
# Out:
#        Country          Region  Happiness Score  \
# 0      Finland  Western Europe           7.8087
# 1      Denmark  Western Europe           7.6456
# 2  Switzerland  Western Europe           7.5599
# 3      Iceland  Western Europe           7.5045
# 4       Norway  Western Europe           7.4880
#
#    Standard error of Happiness score  Upper Confidence Interval  \
# 0                           0.031156                   7.869766
# 1                           0.033492                   7.711245
# 2                           0.035014                   7.628528
# 3                           0.059616                   7.621347
# 4                           0.034837                   7.556281
#
#    Lower Confidence Interval  Economy (GDP per Capita)  Social Support  \
# 0                   7.747634                 10.639267        0.954330
# 1                   7.579955                 10.774001        0.955991
# ...

# %%
df_20.shape
# Out:
# (153, 22)

# %% [markdown]
# ### Preparing dataset 2021

# %%
# Join path orders.csv
df_21 = pd.read_csv(os.path.join(path,'2021.csv'), index_col = False)

# %%
df_21.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# rename columns
df_21.rename(columns = {'Social support':'Social Support','Logged GDP per capita' : 'Economy (GDP per Capita)','Standard error of ladder score' : 'Standard error of Happiness score','Ladder score in Dystopia' : 'Dystopia score','Dystopia + residual' : 'Dystopia Residual','Regional indicator' : 'Region','Ladder score' : 'Happiness Score', 'Country name':'Country', 'Perceptions of corruption':'Trust (Government Corruption)', 'Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices' : 'Freedom', 'upperwhisker' : 'Upper Confidence Interval', 'lowerwhisker' : 'Lower Confidence Interval'}, inplace = True)

# %%
df_21['Year'] = 2021

# %%
# Since the df_20 dataframe didn't have the "Happiness Rank"- column I created the column by importing the column from the df_15 dataframe. We dont't need a specific key here because we only want the numbers 1 to 153 in that order.
df_21['Happiness Rank'] = df_19['Happiness Rank']

# %%
df_21.head()
# Out:
#        Country          Region  Happiness Score  \
# 0      Finland  Western Europe            7.842
# 1      Denmark  Western Europe            7.620
# 2  Switzerland  Western Europe            7.571
# 3      Iceland  Western Europe            7.554
# 4  Netherlands  Western Europe            7.464
#
#    Standard error of Happiness score  Upper Confidence Interval  \
# 0                              0.032                      7.904
# 1                              0.035                      7.687
# 2                              0.036                      7.643
# 3                              0.059                      7.670
# 4                              0.027                      7.518
#
#    Lower Confidence Interval  Economy (GDP per Capita)  Social Support  \
# 0                      7.780                    10.775           0.954
# 1                      7.552                    10.933           0.954
# ...

# %% [markdown]
# ### Preparing dataset 2022

# %%
# Join path orders.csv
df_22 = pd.read_csv(os.path.join(path,'2022.csv'), index_col = False)

# %%
df_22.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
# rename columns
df_22.rename(columns = {'Happiness score':'Happiness Score','Dystopia (1.83) + residual' : 'Dystopia Residual','RANK' : 'Happiness Rank','Whisker-high' : 'Upper Confidence Interval', 'Whisker-low' : 'Lower Confidence Interval'}, inplace = True)

# %%
df_22 ['Year'] = 2022

# %%
#Merge the two dataframes with 'country' as the key
df_22_merged = df_22.merge(df_region, on = 'Country', indicator = True)

# %%
df_22_merged.head()
# Out:
#    Happiness Rank      Country Happiness Score Upper Confidence Interval  \
# 0               1      Finland           7,821                     7,886
# 1               2      Denmark           7,636                     7,710
# 2               3      Iceland           7,557                     7,651
# 3               4  Switzerland           7,512                     7,586
# 4               5  Netherlands           7,415                     7,471
#
#   Lower Confidence Interval Dystopia Residual Explained by: GDP per capita  \
# 0                     7,756             2,518                        1,892
# 1                     7,563             2,226                        1,953
# 2                     7,464             2,320                        1,936
# 3                     7,437             2,153                        2,026
# 4                     7,359             2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# ...

# %%
df_22_merged['_merge'].value_counts()
# Out:
# both          119
# left_only       0
# right_only      0
# Name: _merge, dtype: int64

# %% [markdown]
# ### Preparing dataset 2023

# %%
# Join path orders.csv
df_23 = pd.read_csv(os.path.join(path,'2023.csv'), index_col = False)

# %%
df_23.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
# rename columns
df_23.rename(columns = {'Social support':'Social Support','Dystopia + residual' : 'Dystopia Residual','Standard error of ladder score' : 'Standard error of Happiness score','Ladder score in Dystopia' : 'Dystopia score','Logged GDP per capita' : 'Economy (GDP per Capita)','Ladder score' : 'Happiness Score', 'Country name':'Country', 'Perceptions of corruption':'Trust (Government Corruption)', 'Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices' : 'Freedom', 'upperwhisker' : 'Upper Confidence Interval', 'lowerwhisker' : 'Lower Confidence Interval'}, inplace = True)

# %%
df_23 ['Year'] = 2023

# %%
# Since the df_20 dataframe didn't have the "Happiness Rank"- column I created the column by importing the column from the df_15 dataframe. We dont't need a specific key here because we only want the numbers 1 to 153 in that order.
df_23['Happiness Rank'] = df_19['Happiness Rank']

# %%
#Merge the two dataframes with 'country' as the key
df_23_merged = df_23.merge(df_region, on = 'Country', indicator = True)

# %%
df_23_merged.head()
# Out:
#        Country  Happiness Score  Standard error of Happiness score  \
# 0      Finland            7.804                              0.036
# 1      Denmark            7.586                              0.041
# 2      Iceland            7.530                              0.049
# 3       Israel            7.473                              0.032
# 4  Netherlands            7.403                              0.029
#
#    Upper Confidence Interval  Lower Confidence Interval  \
# 0                      7.875                      7.733
# 1                      7.667                      7.506
# 2                      7.625                      7.434
# 3                      7.535                      7.411
# 4                      7.460                      7.346
#
#    Economy (GDP per Capita)  Social Support  Health (Life Expectancy)  \
# 0                    10.792           0.969                    71.150
# 1                    10.962           0.954                    71.250
# ...

# %% [markdown]
# ### Merging data sets

# %%
Data= df_15.append([df_15,df_16,df_17_merged,df_18_merged,df_19_merged,df_20,df_21,df_22_merged, df_23_merged])
x = Data.iloc[:, [3]].values
# Out:
# /var/folders/q1/d0sf9cv50yb2q64wy681zzzh0000gn/T/ipykernel_11580/1745812281.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data= df_15.append([df_15,df_16,df_17_merged,df_18_merged,df_19_merged,df_20,df_21,df_22_merged, df_23_merged])

# %%
Data.head()
# Out:
#        Country          Region  Happiness Rank Happiness Score  \
# 0  Switzerland  Western Europe               1           7.587
# 1      Iceland  Western Europe               2           7.561
# 2      Denmark  Western Europe               3           7.527
# 3       Norway  Western Europe               4           7.522
# 4       Canada   North America               5           7.427
#
#    Standard Error  Economy (GDP per Capita)  Social Support  \
# 0         0.03411                   1.39651         1.34951
# 1         0.04884                   1.30232         1.40223
# 2         0.03328                   1.32548         1.36058
# 3         0.03880                   1.45900         1.33095
# 4         0.03553                   1.32629         1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 0                   0.94143  0.66557                        0.41978  ...
# 1                   0.94784  0.62877                        0.14145  ...
# ...

# %%
Data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Social Support',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year', 'Lower Confidence Interval',
#        'Upper Confidence Interval', '_merge',
#        'Standard error of Happiness score', 'Dystopia score',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Explained by: GDP per capita'],
#       dtype='object')

# %% [markdown]
# ### Saving as a new dataset

# %%
# Assign path 2 variable
path2 = '/Users/mariamaske/World Happiness Data/02 Data'

# %%
# exporting Happiness report data
Data.to_csv(os.path.join(path2,'Prepared Data', 'Happiness_data_complete.csv'))
